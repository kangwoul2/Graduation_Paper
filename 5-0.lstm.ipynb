# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import random
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import glob

SEED = 42
np.random.seed(SEED)
random.seed(SEED)
tf.random.set_seed(SEED)

sequence_length = 60

technical_indicators = [
    "sma_50", "ema_20", "wma_20", "macd", "macd_signal", "macd_hist", "tema_20",
    "rsi_14", "roc", "cci_14", "willr_14", "atr_14", "upper_bb", "middle_bb", "lower_bb",
    "obv", "ad", "chaikin_ad"
]

csv_files = glob.glob("*_Train.csv")
df = pd.read_csv(csv_files[0])  

X = df[technical_indicators].values
y = df["label"].values

y = y + 1

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

def create_sequences(X, y, seq_length):
    Xs, ys = [], []
    for i in range(len(X) - seq_length):
        Xs.append(X[i : i + seq_length])
        ys.append(y[i + seq_length])
    return np.array(Xs), np.array(ys)

X_seq, y_seq = create_sequences(X_scaled, y, sequence_length)

X_train, X_test, y_train, y_test = train_test_split(
    X_seq, y_seq, test_size=0.2, random_state=SEED, stratify=y_seq
)

tf.random.set_seed(SEED)

model = Sequential([
    LSTM(64, return_sequences=True, input_shape=(sequence_length, len(technical_indicators))),
    Dropout(0.2),
    LSTM(32),
    Dropout(0.2),
    Dense(3, activation="softmax")  
])

model.compile(optimizer=Adam(learning_rate=0.001), loss="sparse_categorical_crossentropy", metrics=["accuracy"])
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

model.save("LSTM_model.h5")
print("LSTM 모델 저장 완료!")
# Out:
# Epoch 1/50
# C:\Users\marigold\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.3318 - loss: 1.1035 - val_accuracy: 0.3587 - val_loss: 1.0922
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.3635 - loss: 1.0957 - val_accuracy: 0.4022 - val_loss: 1.0878
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.3417 - loss: 1.0946 - val_accuracy: 0.3732 - val_loss: 1.0873
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.3794 - loss: 1.0907 - val_accuracy: 0.3768 - val_loss: 1.0853
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.3599 - loss: 1.0917 - val_accuracy: 0.3986 - val_loss: 1.0841
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.3848 - loss: 1.0893 - val_accuracy: 0.4348 - val_loss: 1.0828
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.3936 - loss: 1.0816 - val_accuracy: 0.4130 - val_loss: 1.0830
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.3956 - loss: 1.0810 - val_accuracy: 0.3841 - val_loss: 1.0845
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.3865 - loss: 1.0782 - val_accuracy: 0.3913 - val_loss: 1.0880
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.3950 - loss: 1.0751 - val_accuracy: 0.4022 - val_loss: 1.0862
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.3901 - loss: 1.0669 - val_accuracy: 0.3804 - val_loss: 1.0875
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.4228 - loss: 1.0645 - val_accuracy: 0.3913 - val_loss: 1.0932
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.4154 - loss: 1.0576 - val_accuracy: 0.3732 - val_loss: 1.0988
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.4281 - loss: 1.0520 - val_accuracy: 0.4022 - val_loss: 1.0951
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.4656 - loss: 1.0414 - val_accuracy: 0.3877 - val_loss: 1.1040
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.4634 - loss: 1.0284 - val_accuracy: 0.3841 - val_loss: 1.1052
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.4486 - loss: 1.0237 - val_accuracy: 0.3732 - val_loss: 1.1055
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.4709 - loss: 1.0144 - val_accuracy: 0.3913 - val_loss: 1.1103
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.4685 - loss: 1.0097 - val_accuracy: 0.3841 - val_loss: 1.1231
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.